# %%
# !nvidia-smi
# Out:
# Tue Feb 11 09:07:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  extra_body={},
  model="deepseek/deepseek-r1:free",
  messages=[
    {
      "role": "user",
      "content": "How a non-technical person can be datascientist?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# Transitioning into data science as a non-technical person is challenging but entirely possible with dedication and a structured approach. Here's a roadmap to guide you:
#
# ### 1. **Build Foundational Knowledge**
#    - **Understand Data Science Basics**: Learn core concepts (e.g., data types, lifecycle, CRISP-DM) through accessible resources like:
#      - *"Data Science for Dummies"* by Lillian Pierson.
#      - **Free Courses**: Coursera’s *"What is Data Science?"* (IBM) or edX’s *"Data Science Essentials"*.
#    - **Basic Statistics**: Start with descriptive statistics (mean, median, distribution) and hypothesis testing using Khan Academy or Coursera’s *"Statistics with Python"* (University of Michigan).
#
# ### 2. **Learn Tools Gradually**
#    - **Excel/Sheets**: Master pivot tables, VLOOKUP, and basic analysis for practical applications.
#    - **Visualization Tools**: Begin with **Tableau Public** or **Power BI** via guided tutorials.
#    - **Programming Basics**:
#      - Start with **Python** via interactive platforms like DataCamp or Codecademy.
#      - Focus on libraries like **Pandas** (data manipulation) and **Matplotlib/Seaborn** (visualization).
#
# ### 3. **Leverage Low/No-Code Platforms**
#    - **Automated Tools**: Use **Google AutoML**, **DataRobot**, or **Microsoft Azure ML** to grasp machine learning concepts without coding.
#    - **Kaggle Kernels**: Explore pre-written code notebooks to understand workflows.
#
# ### 4. **Develop Domain-Driven Projects**
#    - **Apply Industry Knowledge**: Create projects related to your current field (e.g., marketing analytics, healthcare trends).
#    - **Freelance/Volunteer**: Offer data analysis services to non-profits or small businesses using tools like Excel or Tableau.
#
# ### 5. **Showcase Skills Strategically**
#    - **Portfolio Focus**: Highlight projects that solve real problems. Use GitHub for code and Tableau Public/Power BI for dashboards.
#    - **Storytelling**: Frame projects with clear narratives (e.g., "Reduced customer churn by analyzing survey data in Excel").
#
# ### 6. **Target Entry-Level Roles**
#    - **Bridge Roles**: Seek positions like **Business Analyst** or **Data Analyst** to gain experience with SQL/BI tools.
#    - **Emphasize Soft Skills**: Highlight problem-solving, communication, and domain expertise in resumes/interviews.
#
# ### 7. **Network and Learn Continuously**
#    - **Communities**: Join **LinkedIn groups**, local meetups, or Slack channels (e.g., DataTalks.Club).
#    - **Mentorship**: Connect with data professionals via platforms like ADPList for guidance.
#
# ### 8. **Upskill Methodically**
#    - **Advanced Topics**: Gradually learn SQL, cloud platforms (e.g., AWS), and machine learning theory.
#    - **Certifications**: Pursue credentials like Google’s **Data Analytics Certificate** or IBM’s **Data Science Professional Certificate**.
#
# ### 9. **Embrace Your Unique Value**
#    - **Domain Expertise**: Use your non-technical background to interpret data in context (e.g., HR analytics for someone in recruiting).
#    - **Bridge the Gap**: Translate technical insights into actionable business strategies.
#
# ### Key Takeaway:
# Start with **low-code tools and your domain expertise**, then layer in technical skills through hands-on projects. Progress to Python/SQL as you grow. Your ability to contextualize data in your industry can set you apart from purely technical candidates. Celebrate incremental progress—transitioning takes time, but each step builds credibility.
